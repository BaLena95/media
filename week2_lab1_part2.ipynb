# %%
For this assignment you can use the movies dataset (movies) or the books dataset. 
When using the movies dataset combine the movies_metadata.csv and ratings_small.cvs or ratings.csv in Pandas. 
Create recommendations based on these reviews. So people who reviewed A also reviewed B. 
Best is to downsize the dataset in order to test the code before it runs for a while.

# %%
# import libraries
import pandas as pd

# load the datasets
# movie metadata
movies_meta = pd.read_csv('movies_metadata.csv', low_memory=False)
# and the keywords
movies_ratings = pd.read_csv('ratings.csv', low_memory=False)

# quick preview
movies_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movies_meta = movies_meta.drop([19730, 29503, 35587])
movies_meta['id'] = movies_meta['id'].astype('int')

# %%
# rename the column name in movies_meta

movies_meta.rename(columns = {'id':'movieId'}, inplace = True) 

movies_meta.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage  movieId    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story      862  tt0114709                en
# ...

# %%
# first need to combine the two 
movies_merged = movies_ratings.merge(movies_meta, on='movieId')
movies_merged.head()
# Out:
#    userId  movieId  rating   timestamp  adult  \
# 0       1      110     1.0  1425941529  False
# 1      11      110     3.5  1231676989  False
# 2      22      110     5.0  1111937009  False
# 3      24      110     5.0   979870012  False
# 4      29      110     3.0  1044020005  False
#
#                                belongs_to_collection budget  \
# 0  {'id': 131, 'name': 'Three Colors Collection',...      0
# 1  {'id': 131, 'name': 'Three Colors Collection',...      0
# 2  {'id': 131, 'name': 'Three Colors Collection',...      0
# 3  {'id': 131, 'name': 'Three Colors Collection',...      0
# 4  {'id': 131, 'name': 'Three Colors Collection',...      0
#
#                                               genres homepage    imdb_id  ...  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# ...

# %%
# see what a specific user e.g 110 rated
movies_merged[movies_merged['userId'] == 110].head(4)
# Out:
#          userId  movieId  rating   timestamp  adult belongs_to_collection  \
# 230583      110     2959     5.0  1447098816  False                   NaN
# 474834      110      260     5.0  1447098819  False                   NaN
# 1560751     110      318     4.5  1447098808  False                   NaN
# 1651826     110     4993     5.0  1447098817  False                   NaN
#
#            budget                                             genres  \
# 230583   35000000                     [{'id': 35, 'name': 'Comedy'}]
# 474834          0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 1560751   8000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 1651826         0  [{'id': 28, 'name': 'Action'}, {'id': 37, 'nam...
#
#                                             homepage    imdb_id  ...  \
# 230583   http://licensetowedthemovie.warnerbros.com/  tt0762114  ...
# 474834                                           NaN  tt0026029  ...
# ...

# %%
from itertools import permutations

# create a function that makes combinations of the movies that a user (x) reviewed
def create_combinations(x):
    combinations = pd.DataFrame(list(permutations(x.values, 2)), columns=['movie_a', 'movie_b'])
    return combinations

# %%
# how many rating by user
avg_user = movies_merged.groupby(['userId']).size().reset_index(name='counts')
avg_user = avg_user.set_index('userId')
avg_user
# Out:
#         counts
# userId
# 1           11
# 2           17
# 3            8
# 4           23
# 5           10
# ...        ...
# 270892      38
# 270893      82
# 270894      58
# 270895      17
# 270896     131
#
# [265917 rows x 1 columns]

# %%
# more than 2 movies rated
avg_user = avg_user[avg_user['counts'] > 2]
users_index = avg_user.index

smaller_selection = movies_merged.iloc[users_index]
smaller_selection.head()
# Out:
#    userId  movieId  rating   timestamp  adult  \
# 1      11      110     3.5  1231676989  False
# 2      22      110     5.0  1111937009  False
# 3      24      110     5.0   979870012  False
# 4      29      110     3.0  1044020005  False
# 5      30      110     5.0   967986311  False
#
#                                belongs_to_collection budget  \
# 1  {'id': 131, 'name': 'Three Colors Collection',...      0
# 2  {'id': 131, 'name': 'Three Colors Collection',...      0
# 3  {'id': 131, 'name': 'Three Colors Collection',...      0
# 4  {'id': 131, 'name': 'Three Colors Collection',...      0
# 5  {'id': 131, 'name': 'Three Colors Collection',...      0
#
#                                               genres homepage    imdb_id  ...  \
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...      NaN  tt0111495  ...
# ...

# %%
smaller_selection.shape
# Out:
# (247214, 27)

# %%
smaller_selection.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp', 'adult',
#        'belongs_to_collection', 'budget', 'genres', 'homepage', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'video', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
# now using the function we created in the beginning
# use the create_combinations function

movie_combinations = smaller_selection.groupby('userId')['title'].apply(create_combinations)
movie_combinations.head(4)
# Out:
#                 movie_a               movie_b
# userId
# 1      0  The 400 Blows  Sleepless in Seattle
#        1  The 400 Blows          Rocky Balboa
#        2  The 400 Blows         Fools Rush In
#        3  The 400 Blows    Young and Innocent

# %%
# calculate the occurences of the movie a and movie b

movie_combinations = movie_combinations.reset_index(drop=True)
combi_count = movie_combinations.groupby(['movie_a', 'movie_b']).size()
combi_count = combi_count.to_frame(name='size').reset_index()
combi_count.sort_values('size', ascending=False).head(5)
# Out:
#                  movie_a               movie_b   size
# 41    Young and Innocent     Three Colors: Red  22732
# 35     Three Colors: Red    Young and Innocent  22732
# 33     Three Colors: Red  Sleepless in Seattle  22217
# 22  Sleepless in Seattle     Three Colors: Red  22217
# 39    Young and Innocent  Sleepless in Seattle  20344

# %%
# search for a specific movie to check 
combi_count[combi_count['movie_a'] == 'Three Colors: Red'].sort_values('size', ascending=False).head(10)
# Out:
#               movie_a               movie_b   size
# 35  Three Colors: Red    Young and Innocent  22732
# 33  Three Colors: Red  Sleepless in Seattle  22217
# 31  Three Colors: Red        License to Wed  15520
# 32  Three Colors: Red          Rocky Balboa  13042
# 30  Three Colors: Red         Fools Rush In  11763
# 34  Three Colors: Red         The 400 Blows   2532
